# %%
import pandas as pd
import plotext as plt
import numpy as np
import world_bank_data as wb
import os 
os.chdir('..')
import src.data.IDH

# %%
df = pd.read_csv('data/processed/idh_index.csv')

# %%
plt.plot(df['Year'], df['index'], color='red', label='Idh Index')
plt.xlabel('Year')
plt.ylabel('Idh Index')
plt.show()
# Out:
#       ┌────────────────────────────────────────────────────────────────────────┐
# 0.8811┤ ▞▞ Idh Index                                                   ▞▖      │
#       │                                                               ▞ ▝▚▖    │
#       │                                                              ▐    ▝▚   │
# 0.8762┤                                                             ▗▘      ▀▄ │
#       │                                                            ▗▘         ▀│
#       │                                                            ▞           │
# 0.8713┤                                                           ▞            │
#       │                           ▗▞▄▖           ▄▀▀▀▀▀▀▀▚▖      ▐             │
# 0.8663┤                         ▄▞▘  ▝▀▄▖     ▄▞▀         ▝▀▄▖  ▗▘             │
#       │                       ▄▀        ▝▀▄▄▞▀               ▝▀▄▌              │
#       │                    ▗▞▀                                                 │
# 0.8614┤                  ▗▞▘                                                   │
#       │                ▗▞▘                                                     │
#       │              ▗▞▘                                                       │
# 0.8565┤         ▗▄▄▀▀▘                                                         │
#       │      ▄▀▀▘                                                              │
#       │   ▄▞▀                                                                  │
# 0.8515┤▄▞▀                                                                     │
#       └┬─────────────────┬─────────────────┬────────────────┬─────────────────┬┘
#     2012.0            2014.5            2017.0           2019.5          2022.0
# Idh Index                                Year
